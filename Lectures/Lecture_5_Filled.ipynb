# %% [markdown]
# # Lecture 5 of 9 - Pandas Fundamentals

# %%
import pandas as pd

# %% [markdown]
# ## Importing Data
# For this lecture we will be analysing the 'LSTM-Multivariate_pollution.csv' dataset from Canvas. Make sure this file is uploaded in your current JupyterLab folder before continuing. Then use the <code>read_csv</code> function to import as a dataframe.

# %%
# import the data using the read_csv function
pollution_data = pd.read_csv('Data/LSTM-Multivariate_pollution.csv', index_col='date')
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
# [43800 rows x 8 columns]

# %% [markdown]
# ## Inspecting Data
# Use data inspection tools to answer the following questions:
# 1. How many observations are in the data?
#    43800
# 3. How many columns are in the data?
#    8
# 5. What are the column names? ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow',
#        'rain']
# 6. What is the data type of each column?
# 7. What is the dataframe index? What data type does it have?

# %%
pollution_data.shape
# Out:
# (43800, 8)

# %%
pollution_data.columns
# Out:
# Index(['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow',
#        'rain'],
#       dtype='object')

# %%
pollution_data.dtypes
# Out:
# pollution      int64
# dew            int64
# temp         float64
# press        float64
# wnd_dir       object
# wnd_spd      float64
# snow           int64
# rain           int64
# dtype: object

# %%
pollution_data.index
# Out:
# Index(['2/01/2010 0:00', '2/01/2010 1:00', '2/01/2010 2:00', '2/01/2010 3:00',
#        '2/01/2010 4:00', '2/01/2010 5:00', '2/01/2010 6:00', '2/01/2010 7:00',
#        '2/01/2010 8:00', '2/01/2010 9:00',
#        ...
#        '31/12/2014 14:00', '31/12/2014 15:00', '31/12/2014 16:00',
#        '31/12/2014 17:00', '31/12/2014 18:00', '31/12/2014 19:00',
#        '31/12/2014 20:00', '31/12/2014 21:00', '31/12/2014 22:00',
#        '31/12/2014 23:00'],
#       dtype='object', name='date', length=43800)

# %%
pollution_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43800 entries, 2/01/2010 0:00 to 31/12/2014 23:00
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pollution  43800 non-null  int64
#  1   dew        43800 non-null  int64
#  2   temp       43800 non-null  float64
#  3   press      43800 non-null  float64
#  4   wnd_dir    43800 non-null  object
#  5   wnd_spd    43800 non-null  float64
#  6   snow       43800 non-null  int64
#  7   rain       43800 non-null  int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 3.0+ MB

# %%
pollution_data.describe()
# Out:
#           pollution           dew          temp         press       wnd_spd  \
# count  43800.000000  43800.000000  43800.000000  43800.000000  43800.000000
# mean      94.013516      1.828516     12.459041   1016.447306     23.894307
# std       92.252276     14.429326     12.193384     10.271411     50.022729
# min        0.000000    -40.000000    -19.000000    991.000000      0.450000
# 25%       24.000000    -10.000000      2.000000   1008.000000      1.790000
# 50%       68.000000      2.000000     14.000000   1016.000000      5.370000
# 75%      132.250000     15.000000     23.000000   1025.000000     21.910000
# max      994.000000     28.000000     42.000000   1046.000000    585.600000
#
#                snow          rain
# count  43800.000000  43800.000000
# mean       0.052763      0.195023
# std        0.760582      1.416247
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       27.000000     36.000000

# %% [markdown]
# ## Selecting Data
# Data can be selected by label using <code>loc</code> or by index using <code>iloc</code>.
#
# General syntax for <code>loc</code> is </code>df_name.loc[row_label, col_label]</code>
#
# General syntax for <code>iloc</code> is </code>df_name.iloc[row_index, col_index]</code>

# %%
# select the temp column
pollution_data.temp
# Out:
# date
# 2/01/2010 0:00     -4.0
# 2/01/2010 1:00     -4.0
# 2/01/2010 2:00     -5.0
# 2/01/2010 3:00     -5.0
# 2/01/2010 4:00     -5.0
#                    ...
# 31/12/2014 19:00   -2.0
# 31/12/2014 20:00   -3.0
# 31/12/2014 21:00   -3.0
# 31/12/2014 22:00   -4.0
# 31/12/2014 23:00   -3.0
# Name: temp, Length: 43800, dtype: float64

# %%
pollution_data['temp']
# Out:
# date
# 2/01/2010 0:00     -4.0
# 2/01/2010 1:00     -4.0
# 2/01/2010 2:00     -5.0
# 2/01/2010 3:00     -5.0
# 2/01/2010 4:00     -5.0
#                    ...
# 31/12/2014 19:00   -2.0
# 31/12/2014 20:00   -3.0
# 31/12/2014 21:00   -3.0
# 31/12/2014 22:00   -4.0
# 31/12/2014 23:00   -3.0
# Name: temp, Length: 43800, dtype: float64

# %%
pollution_data.loc[:, 'temp']
# Out:
# date
# 2/01/2010 0:00     -4.0
# 2/01/2010 1:00     -4.0
# 2/01/2010 2:00     -5.0
# 2/01/2010 3:00     -5.0
# 2/01/2010 4:00     -5.0
#                    ...
# 31/12/2014 19:00   -2.0
# 31/12/2014 20:00   -3.0
# 31/12/2014 21:00   -3.0
# 31/12/2014 22:00   -4.0
# 31/12/2014 23:00   -3.0
# Name: temp, Length: 43800, dtype: float64

# %%
# select the row at 1/01/2012 0:00
pollution_data.loc['1/01/2012 0:00', :]
# Out:
# pollution       275
# dew             -12
# temp           -8.0
# press        1030.0
# wnd_dir          NE
# wnd_spd        0.89
# snow              0
# rain              0
# Name: 1/01/2012 0:00, dtype: object

# %%
pollution_data.loc['1/01/2012 0:00']
# Out:
# pollution       275
# dew             -12
# temp           -8.0
# press        1030.0
# wnd_dir          NE
# wnd_spd        0.89
# snow              0
# rain              0
# Name: 1/01/2012 0:00, dtype: object

# %%
# select the pollution at 5/03/2013 21:00
pollution_data.loc['5/03/2013 21:00', 'pollution']
# Out:
# np.int64(263)

# %%
# select all observations from March 2011
pollution_data.loc['1/03/2011 0:00':'31/03/2011 23:00'] # pandas slicing includes the final value
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 1/03/2011 0:00           12  -11  -1.0  1028.0      NW    93.44     0     0
# 1/03/2011 1:00            9  -12  -2.0  1028.0      NE     3.13     0     0
# 1/03/2011 2:00            9  -12  -4.0  1028.0      NW     3.13     0     0
# 1/03/2011 3:00           11  -12  -4.0  1028.0      NW     6.26     0     0
# 1/03/2011 4:00           17  -12  -3.0  1028.0      NW     8.05     0     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/03/2011 19:00          0    4  17.0  1013.0      cv     1.78     0     0
# 31/03/2011 20:00          0    4  14.0  1014.0      NE     0.89     0     0
# 31/03/2011 21:00        295    4  12.0  1015.0      cv     0.89     0     0
# 31/03/2011 22:00        328    3  14.0  1016.0      NE     3.13     0     0
# 31/03/2011 23:00        287    3  14.0  1016.0      NE     6.26     0     0
#
# [744 rows x 8 columns]

# %%
pollution_data.loc[:, 'pollution': 'temp']
# Out:
#                   pollution  dew  temp
# date
# 2/01/2010 0:00          129  -16  -4.0
# 2/01/2010 1:00          148  -15  -4.0
# 2/01/2010 2:00          159  -11  -5.0
# 2/01/2010 3:00          181   -7  -5.0
# 2/01/2010 4:00          138   -7  -5.0
# ...                     ...  ...   ...
# 31/12/2014 19:00          8  -23  -2.0
# 31/12/2014 20:00         10  -22  -3.0
# 31/12/2014 21:00         10  -22  -3.0
# 31/12/2014 22:00          8  -22  -4.0
# 31/12/2014 23:00         12  -21  -3.0
#
# [43800 rows x 3 columns]

# %%
# can select by providing a list of labels
pollution_data.loc[:, ['temp', 'rain']]
# Out:
#                   temp  rain
# date
# 2/01/2010 0:00    -4.0     0
# 2/01/2010 1:00    -4.0     0
# 2/01/2010 2:00    -5.0     0
# 2/01/2010 3:00    -5.0     0
# 2/01/2010 4:00    -5.0     0
# ...                ...   ...
# 31/12/2014 19:00  -2.0     0
# 31/12/2014 20:00  -3.0     0
# 31/12/2014 21:00  -3.0     0
# 31/12/2014 22:00  -4.0     0
# 31/12/2014 23:00  -3.0     0
#
# [43800 rows x 2 columns]

# %%
# select the element in the 100th row and the 4th column
pollution_data.iloc[99, 3] # zero based like lists
# Out:
# np.float64(1033.0)

# %% [markdown]
# ## Filtering Data
# Data can be filtered using Boolean arrays just like you saw with NumPy arrays last week. This allows for data to be selected if a certain condition is True.
#
# The general syntax is <code>df_name[condition]</code> and reads select the dataframe for each row where the condition is True.

# %%
pollution_data.temp < 0
# Out:
# date
# 2/01/2010 0:00      True
# 2/01/2010 1:00      True
# 2/01/2010 2:00      True
# 2/01/2010 3:00      True
# 2/01/2010 4:00      True
#                     ...
# 31/12/2014 19:00    True
# 31/12/2014 20:00    True
# 31/12/2014 21:00    True
# 31/12/2014 22:00    True
# 31/12/2014 23:00    True
# Name: temp, Length: 43800, dtype: bool

# %%
# select all rows where the temperature is below zero
pollution_data[pollution_data.temp < 0]
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
# [8590 rows x 8 columns]

# %%
# select all the rows where there is snow
pollution_data[pollution_data.snow > 0]
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# 2/01/2010 5:00          109   -7  -6.0  1022.0      SE     7.14     3     0
# 2/01/2010 6:00          105   -7  -6.0  1023.0      SE     8.93     4     0
# 2/01/2010 10:00         140   -7  -5.0  1026.0      SE    17.43     1     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 13/02/2014 10:00        205  -11  -3.0  1038.0      SE    57.67     2     0
# 18/02/2014 23:00        123  -11  -2.0  1029.0      SE     2.68     1     0
# 20/02/2014 8:00         184   -5  -2.0  1032.0      SE     3.57     1     0
# 20/02/2014 9:00         190   -5  -1.0  1032.0      SE     5.36     2     0
# 10/12/2014 0:00         311   -6  -1.0  1029.0      cv     0.89     1     0
#
# [368 rows x 8 columns]

# %%
# select all rows that are below zero and don't have snow
# need to use bitwise operators &, |, ~
# bitwise operators occur before relational operators (eg. >, < ==)

pollution_data[(pollution_data.temp < 0) & (pollution_data.snow == 0)]
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 7:00          124   -7  -5.0  1024.0      SE    10.72     0     0
# 2/01/2010 8:00          120   -8  -6.0  1024.0      SE    12.51     0     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
# [8276 rows x 8 columns]

# %%
# select all rows that have rain or snow
pollution_data[(pollution_data.rain > 0) | (pollution_data.snow > 0)]
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# 2/01/2010 5:00          109   -7  -6.0  1022.0      SE     7.14     3     0
# 2/01/2010 6:00          105   -7  -6.0  1023.0      SE     8.93     4     0
# 2/01/2010 10:00         140   -7  -5.0  1026.0      SE    17.43     1     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/10/2014 11:00        150   10  14.0  1021.0      cv     3.57     0     1
# 31/10/2014 13:00        143   10  15.0  1020.0      SE     3.58     0     1
# 31/10/2014 14:00        143   10  15.0  1019.0      SE     5.37     0     2
# 29/11/2014 18:00        343    2   4.0  1020.0      NE     0.89     0     1
# 10/12/2014 0:00         311   -6  -1.0  1029.0      cv     0.89     1     0
#
# [2176 rows x 8 columns]

# %% [markdown]
# ## Computed Columns
# A computed column is a column that is calculated based on other columns in the dataframe. These are generally calculated by using element-wise operators (you should remember these from when you learned about arrays). If you need to define you own custom function for computations, it can be applied element-wise by calling the <code>apply</code> method.

# %%
# create a new column that includes the pressure measured in atmospheres 
# (note: the current pressure column is measured in millibars).

pollution_data['press_atm'] = pollution_data.press * 0.00098692
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
#                   press_atm
# date
# 2/01/2010 0:00     1.006658
# 2/01/2010 1:00     1.006658
# 2/01/2010 2:00     1.007645
# 2/01/2010 3:00     1.008632
# 2/01/2010 4:00     1.008632
# ...                     ...
# 31/12/2014 19:00   1.020475
# 31/12/2014 20:00   1.020475
# 31/12/2014 21:00   1.020475
# 31/12/2014 22:00   1.020475
# 31/12/2014 23:00   1.020475
#
# [43800 rows x 9 columns]

# %%
# create a new column that specified whether the temperatures is above or below freezing point (0 degrees)
pollution_data['is_freezing'] = pollution_data.temp <= 0
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
#                   press_atm  is_freezing
# date
# 2/01/2010 0:00     1.006658         True
# 2/01/2010 1:00     1.006658         True
# 2/01/2010 2:00     1.007645         True
# 2/01/2010 3:00     1.008632         True
# 2/01/2010 4:00     1.008632         True
# ...                     ...          ...
# 31/12/2014 19:00   1.020475         True
# 31/12/2014 20:00   1.020475         True
# 31/12/2014 21:00   1.020475         True
# 31/12/2014 22:00   1.020475         True
# 31/12/2014 23:00   1.020475         True
#
# [43800 rows x 10 columns]

# %%
def climate_cat(df):
    if df.temp < 10:
        climate = 'cold'
    elif df.temp < 25:
        climate = 'warm'
    else:
        climate = 'hot'
    return climate

pollution_data.apply(climate_cat, axis=1)
# Out:
# date
# 2/01/2010 0:00      cold
# 2/01/2010 1:00      cold
# 2/01/2010 2:00      cold
# 2/01/2010 3:00      cold
# 2/01/2010 4:00      cold
#                     ...
# 31/12/2014 19:00    cold
# 31/12/2014 20:00    cold
# 31/12/2014 21:00    cold
# 31/12/2014 22:00    cold
# 31/12/2014 23:00    cold
# Length: 43800, dtype: object

# %% [markdown]
# ## Aggregates
# Aggregates are used to summarise information in a dataset. They condense many observations down to a single number to describe a property of that variable.
#
# In pandas, these aggregates are stored as methods, meaning the general syntax is <code>df_name.method_name(arguments)</code>.

# %%
# find the average pollution
pollution_data.pollution.mean()
# Out:
# np.float64(94.01351598173515)

# %%
# find the max pollution. at what time did this occur?
max_pollution = pollution_data.pollution.max()
pollution_data[pollution_data.pollution == max_pollution]
# Out:
#                  pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 23/01/2012 1:00        994  -24 -12.0  1032.0      NW     4.92     0     0
#
#                  press_atm  is_freezing
# date
# 23/01/2012 1:00   1.018501         True

# %%
# find the percentage of observations that have a temperature below zero
n_below_zero = (pollution_data.temp < 0).sum()
n_obs = len(pollution_data.temp)
n_below_zero / n_obs * 100
# Out:
# np.float64(19.61187214611872)

# %% [markdown]
# ## Visualising Data (introduction)
# In pandas you can visualise data with the <code>plot</code> method. This method has lots of potential arguments which can be found here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html. The main ones to consider when starting out are:
#
# <code>x</code>: this is a label that describes what column of the dataframe goes on the x-axis of the plot. Defaults to the index of the series/dataframe.
#
# <code>y</code>: this is a label that describes what column of the dataframe foes on the y-axis of the plot. Defaults to all columns of the series/dataframe.
#
# <code>kind</code>: this is a string describing what type of plot to create. Some notable types are given below:
# * 'line' (default)
# * 'bar'
# * 'barh'
# * 'hist'
# * 'box'
# * 'kde' / 'density'
# * 'pie'
# * 'scatter'

# %%
# plot examples
pollution_data.plot(x='temp', y='pollution', kind='scatter')
# Out:
# <Axes: xlabel='temp', ylabel='pollution'>

# %%
pollution_data.plot(y='temp')
# Out:
# <Axes: xlabel='date'>

# %%
pollution_data.plot()
# Out:
# <Axes: xlabel='date'>

# %%
pollution_data.plot(y='pollution', kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pollution_data.groupby('wnd_dir').pollution.mean()
# Out:
# wnd_dir
# NE     85.845677
# NW     66.921515
# SE    105.624787
# cv    120.236893
# Name: pollution, dtype: float64
