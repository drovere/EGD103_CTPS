# %% [markdown]
# <div style="background-color: #ccccff ; padding:10px; font-size:x-large; font-weight: bold">
# EGD103 Assignment 1B - The Harvesting Robot
# </div>

# %% [markdown]
# In this assignment, you will be applying some tasks involving the programming of a small robot that moves in 2D space. The project is inspired by harvesting robots which are becoming increasingly popular in agricultural applications.
#
#
# <img style="display: block; margin: 0 auto" width="400" src=https://howtorobot.com/sites/default/files/2023-03/shutterstock_1995250223.jpg>
# <p style="text-align: center;"> Source: https://howtorobot.com/expert-insight/harvesting-robots </p>
#
# This assignment is split into two parts:
# * **Part A (10%)** was completed in week 2.
# * **Part B (20%)** is contained in this template and is due Friday week 4.

# %% [markdown]
# <div style="background-color: #ffcccc; padding:10px">
#
# ## General Rules and Restrictions
# * You must use Jupyter in the cloud (on https://jupyter.eres.qut.edu.au) to develop your solution.
# * For the assignments you cannot work with friends or colleagues, or get help from anyone other than the EGD103 teaching team - it needs to be entirely your own work.
# * You cannot use AI tools such as ChatGPT or Copilot to help develop your solution.
# * Do not modify any function names, parameters or test cases provided in this notebook.
# * Every function must be implemented in only one place within this .ipynb file (where it is already defined). Do not cut and paste to create duplicate definitions of the same function.
# * Do not add any import statements. The only modules you are allowed to import are the ones that have been imported for you within this assignment template.
# * You should only use Python language features that have been taught within this unit. If you use other features we will suspect acadamic misconduct and require you to attend meeting to authenticate your learning.
# </div>

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## Student Details
# <p>Task: Using the Markdown cell below, write your name and student number. Also briefly describe any previous programming experience you may have had (if any).</p>

# %% [markdown]
# * Name:
# * Student number:
# * Previous programming experience:

# %% [markdown]
# ***
# ## B1: Introduction
# In part A, you modelled some simple functions that implemented logic to decide which way a robot should move so that it moves one space towards a targed object.
#
# In part B, you will simulate a robot moving around a grid and collecting all objects. You will implement an algorithm that can decide a "smart order" to collect the objects in.
#
# The robot's position will be represented the same as assignment 1A - with a 2-element (x, y) tuple. Eg. <code>(5, 3)</code>.
#
# The object positions will be represented as a list of (x, y) tuples. Eg. <code>[(1, 3), (5, 2), (8, 12)]</code> is a list containing positions of 3 objects.

# %% [markdown]
# ## B2: The <code>robot<code> module
# A module named <code>robot</code> is provided for you to help complete the assignment. This module contains the following functions you will be calling:
# * <code>move</code> - moves a robot one space towards the first object from a list of objects. Logic is different to your function from 1A.
# * <code>collect</code> - collects an object if the robot is in the same position as the object by removing it from the list of objects.
# * <code>initialise_positions</code> - outputs an initial robot position and a list of initial object positions. Can specify a seed for random number generation and the number of objects to generate.
#
# It also contains some other functions used for testing your code. These are already called in the template - you will not be using these functions yourself.
#
# To make sure you're familiar with this module, we will get you to call the functions to simulate a robot collecting a single object.

# %%
# run this cell so the robot module is imported for the rest of your assignment
import robot

# %%
# you can find help documentation on each function by calling the help function
# example
help(robot.initialise_positions)

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# <p>Task: Call the <code>initialise_positions</code> function from the <code>robot</code> module to return a robot position and 5 object positions using a seed of 486. Store the robot and object positions in separate variables.</p>

# %%
# write your code here

# should get a robot position of (63, 39)
# should get an object positions list of [(63, 38), (62, 32), (63, 49), (22, 22), (22, 28)]

# %% [markdown]
# You should see that the initial positions have the robot <code>(63, 39)</code> only one space away from the first object in the object list<code>(63, 38)</code>. Let's now move the robot to the object.
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# <p>Task: Call the <code>move</code> function from the <code>robot</code> module to move the robot to the object. Make sure to use the robot position variable you defined earlier in your solution. Store the new robot position in a variable.</p>

# %%
# write your code here

# should get a robot position of (63, 38)

# %% [markdown]
# You should now see that the robot and object are in the same position. Let's pick up the object.
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# <p>Task: Call the <code>collect</code> function from the <code>robot</code> module to collect the object. Make sure to use the most recently defined robot position and object positions variables in your solution.</p>

# %%
# write your code here

# should get an answer of [(62, 32), (63, 49), (22, 22), (22, 28)]

# %% [markdown]
# ## B3: Simulate one time step
# Now that you know how to move the robot and collect an object using the robot module, we can simulate one time step for the robot. To do this, the robot will need to decide which action to perform - move or collect. It should collect if robot has the same position as one of the objects. Otherwise, it should move.
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# Task: Create a function below that accepts two inputs: a robot position tuple and a list of object position tuples. It should output an updated robot position and list of object positions after one time step (either collecting an object, or moving one tile per the above instructions).

# %%
def simulate_one_time_step(robot_position, object_positions):
    # replace this comment and pass with your solution
    pass

# %%
# test case 1 - moving
robot_position, object_positions = simulate_one_time_step((9, 0), [(4, 9), (5, 7), (9, 2)])
print(robot_position) # should return (9, 1)
print(object_positions) # should return [(4, 9), (5, 7), (9, 2)]

# %%
# test case 2 - moving
robot_position, object_positions = simulate_one_time_step((0, 0), [(4, 9), (5, 7), (9, 2)])
print(robot_position) # should return (0, 1)
print(object_positions) # should return [(4, 9), (5, 7), (9, 2)]

# %%
# test case 3 - collecting
robot_position, object_positions = simulate_one_time_step((9, 2), [(4, 9), (5, 7), (9, 2)])
print(robot_position) # should return (9, 2)
print(object_positions) # should return [(4, 9), (5, 7)]

# %% [markdown]
# ## B4: Computing distance
# The movement logic of the robot is very simple - it always chooses to move towards the first object in the list. Since object positions are randomly generated, the robot will usually take a very inefficient path to collect the objects.
#
# A simple way to ensure the robot collects objects efficiently is to always collect the object that is nearest to the robot. Since the robot can only move up, down, left or right, we can not use standard Euclidean distance as a measure. Instead, we need to use $L_1$ distance (also commonly known as taxicab or Manhattan distance), which is given by:
# $$ d(\vec{a},\vec{b}) = |b_x - a_x| + |b_y - a_y|$$
# where $d(\vec{a},\vec{b})$ is the distance between objects at position $\vec{a}$ and position $\vec{b}$
#
# More information can be found here if needed: https://en.wikipedia.org/wiki/Taxicab_geometry
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# Task: Create a function that accepts two input position tuples: one for the robot and one for the object to be collected. The function should return the L1 distance between the two objects.

# %%
def compute_L1_distance(robot_position, object_position):
    # replace pass and this comment with your own solution
    pass

# %%
# test case 1 - should return 4
compute_L1_distance((5, 8), (3, 6))

# %%
# test case 2 - should return 7
compute_L1_distance((7, 2), (2, 4))

# %% [markdown]
# ## B5: Finding nearest object
# Now that we have a way of measuring distance, we need a way of determining which object in a list is closest to the robot.
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# Task: Create a function with two arguments: a robot position tuple and a list of object position tuples. The function should return the object position tuple that is closest to the robot. If it there is a tie, it should choose the object that appears earlier in the list. If the object positions list is empty, the function should return <code>None</code>. Make sure to call your function from B4 in your solution.

# %%
def find_nearest_object(robot_position, object_positions):
    # replace pass and this comment with your own solution
    pass

# %%
# test case 1 - should output (2, 1)
find_nearest_object((0, 0), [(2, 1), (5, 7), (9, 3)])

# %%
# test case 2 - should output (5, 7)
find_nearest_object((7, 5), [(2, 1), (5, 7), (9, 3)])

# %%
# test case 3 - should output (9, 3)
find_nearest_object((7, 5), [(2, 1), (9, 3), (5, 7)])

# %%
# test case 4 - should return None (ie. display nothing)
find_nearest_object((7, 5), [])

# %% [markdown]
# ## B6: Sorting the object positions
# Now that you can find the nearest object to the robot, you can now utilise this to help sort the object positions list. We want it to be sorted so that the robot always moves to the closest object (both initially, and then after collecting any object).
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# Task: Create a function with two arguments: a robot position tuple and a list of object position tuples. The function should return a sorted list of object position tuples such that the robot always moves to the object it is closest to. Make sure to call your function from B5 in your solution.

# %%
def sort_object_positions(robot_position, object_positions):
    # replace pass and this comment with your own solution
    pass

# %%
# test case 1 - should return [(9, 3), (5, 7), (2, 1)]
sort_object_positions((7, 4), [(2, 1), (9, 3), (5, 7)])

# %%
# test case 2 - should return [(1, 1), (2, 4), (5, 1), (7, 0), (5, 9)]
sort_object_positions((0, 0), [(1, 1), (5, 9), (2, 4), (7, 0), (5, 1)])

# %%
# test case 3 - should return [(7, 4), (9, 2), (3, 8), (2, 9)]
sort_object_positions((0, 0), [(7, 4), (3, 8), (2, 9), (9, 2)])

# %%
# test case 4 - should return []
sort_object_positions((5, 4), [])

# %% [markdown]
# ## B7: Collecting all objects
# Now that we are able to sort the objects in a "smart order" for collection, we want you to simulate the robot collecting all objects on a board.
#
# Your code should store the robot position and objects positions in a list after initialisation and each time step of the simulation. It should simulate until all objects have been collected. At the point, it should return the list of robot positions and the list of object positions (in that order).
#
# The function will have 3 default arguments:
# * <code>seed</code> Defaults to 1. Seed needs to be passed to the initialise_positions function when you call it.
# * <code>object_count</code>. Defaults to 10. Allows to change the number of objects to collect if desired.
# * <code>smart_order</code>. Defaults to False. Your code should sort the object positions into a "smart order" if this is True. Otherwise, it shouldn't sort the positions.
#
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
# <p>Task: Create a function that simulates the robot collecting all objects as per the specifications above.</p>

# %%
def simulate_robot(seed=1, object_count=10, smart_order=False):
    # replace pass and this comment with your own solution
    pass

# %%
# collecting one object
robot_positions, object_positions_list = simulate_robot(seed=325, object_count=1)

# should return [(72, 15), (72, 16), (71, 16), (70, 16), (70, 16)]
print(robot_positions)

# should return [[(70, 16)], [(70, 16)], [(70, 16)], [(70, 16)], []]
print(object_positions_list)

# %%
# collecting 2 objects
robot_positions, object_positions_list = simulate_robot(seed=365757, object_count=2)

# should return [(58, 6), (58, 5), (59, 5), (59, 5), (59, 6), (59, 7), (59, 7)]
print(robot_positions)

# should return [[(59, 5), (59, 7)], [(59, 5), (59, 7)], [(59, 5), (59, 7)], [(59, 7)], [(59, 7)], [(59, 7)], []]
print(object_positions_list)

# %%
# collecting many objects - compare to video on Canvas
robot_positions, object_positions_list = simulate_robot()
robot.animate_robot(robot_positions, object_positions_list)

# %%
# collecting many objects - compare to video on Canvas
robot_positions, object_positions_list = simulate_robot(smart_order=False)
robot.animate_robot(robot_positions, object_positions_list)

# %% [markdown]
# <div style="background-color: #b2efb2; padding:10px; font-size:small; font-weight: bold">
#
# ## B8: Learning reflection (approx 400 words)
#
# <p>Write a reflection of your learning from completing this assignment in the Markdown cell below.
#
# Examples of things you might want to discuss include:
# * Programming concepts you learned.
# * Errors you made and how you troubleshooted them.
# * Earlier drafts of code and how you improved them.
# * Resources from EGD103 you found most useful when completing the assignment.
# * Good programming practices you developed.
# * Areas of improvement.
#
# The word count is suggestive and won't be rigidly enforced as a limit. Supplementary code provided will not be counted towards the word count.
# </p>

# %% [markdown]
# Write your learning reflection here.

# %%
# Can insert any code that supports your reflection here
# (eg. initial errors you made, earlier versions of code that you improved on)
