# %% [markdown]
# ## Updating a dataframe
# There are many ways you may want to update a dataframe in order to modify it into a more presentable form. Some common tools to update a dataframe are described below. Note that this is not an exhaustive list, and you may need to consult pandas documentation for tasks not mentioned here.
#
# Note that all the examples below use the domestic_flights.csv Download domestic_flights.csvdataset. It can be imported with the code:

# %%
import pandas as pd
flights = pd.read_csv('domestic_flights.csv')
flights
# Out:
#           City1          City2   Month  Passenger_Trips  Aircraft_Trips  \
# 0      ADELAIDE  ALICE SPRINGS  Jan-84            15743             143
# 1      ADELAIDE       BRISBANE  Jan-84             3781              32
# 2      ADELAIDE       CANBERRA  Jan-84             1339              12
# 3      ADELAIDE         DARWIN  Jan-84             3050              33
# 4      ADELAIDE     GOLD COAST  Jan-84             1596              16
# ...         ...            ...     ...              ...             ...
# 25962    SYDNEY    WAGGA WAGGA  Apr-22            11318             326
# 25963    SYDNEY    WAGGA WAGGA  May-22            12278             351
# 25964    SYDNEY    WAGGA WAGGA  Jun-22            12119             338
# 25965    SYDNEY    WAGGA WAGGA  Jul-22            12863             415
# 25966    SYDNEY    WAGGA WAGGA  Aug-22            12971             443
#
#        Route_Distance  Seats
# 0                1316  19246
# 1                1622   4210
# 2                 972   1414
# 3                2619   4566
# 4                1607   1803
# ...               ...    ...
# 25962             367  17244
# 25963             367  18599
# 25964             367  18116
# 25965             367  20302
# 25966             367  21366
#
# [25967 rows x 7 columns]

# %% [markdown]
# ### Adding new columns
#
# New columns can be added to a dataframe through assignment, provided the column name doesn't already exist in the dataframe. The general format is <code>df_name['col_name'] = ....</code> If the column name provided does exist, it will instead update that column.

# %%
# example: adding a column with total distance.
flights['Total_Distance'] = flights['Route_Distance'] * flights['Aircraft_Trips']

# %% [markdown]
# ### Removing columns
#
# If you want to remove a small amount of columns, then you should use the <code>drop</code> method and use the <code>columns</code> argument to specify what columns to remove. Note: this doesn't update the dataframe in place, so you will need to assign to a variable to store the modified dataframe.

# %%
# removing route distance column
flights.drop(columns = 'Route_Distance')
# Out:
#           City1          City2   Month  Passenger_Trips  Aircraft_Trips  \
# 0      ADELAIDE  ALICE SPRINGS  Jan-84            15743             143
# 1      ADELAIDE       BRISBANE  Jan-84             3781              32
# 2      ADELAIDE       CANBERRA  Jan-84             1339              12
# 3      ADELAIDE         DARWIN  Jan-84             3050              33
# 4      ADELAIDE     GOLD COAST  Jan-84             1596              16
# ...         ...            ...     ...              ...             ...
# 25962    SYDNEY    WAGGA WAGGA  Apr-22            11318             326
# 25963    SYDNEY    WAGGA WAGGA  May-22            12278             351
# 25964    SYDNEY    WAGGA WAGGA  Jun-22            12119             338
# 25965    SYDNEY    WAGGA WAGGA  Jul-22            12863             415
# 25966    SYDNEY    WAGGA WAGGA  Aug-22            12971             443
#
#        Seats  Total_Distance
# 0      19246          188188
# 1       4210           51904
# 2       1414           11664
# 3       4566           86427
# 4       1803           25712
# ...      ...             ...
# 25962  17244          119642
# 25963  18599          128817
# 25964  18116          124046
# 25965  20302          152305
# 25966  21366          162581
#
# [25967 rows x 7 columns]

# %% [markdown]
# Selecting what columns you want to keep (using loc or iloc) is also viable.

# %% [markdown]
# ### Removing rows
#
# Row removal is similar to column removal. You can use the <code>drop</code> method to remove a select few rows.

# %%
# removing first row of the data
flights.drop(0)
# Out:
#           City1        City2   Month  Passenger_Trips  Aircraft_Trips  \
# 1      ADELAIDE     BRISBANE  Jan-84             3781              32
# 2      ADELAIDE     CANBERRA  Jan-84             1339              12
# 3      ADELAIDE       DARWIN  Jan-84             3050              33
# 4      ADELAIDE   GOLD COAST  Jan-84             1596              16
# 5      ADELAIDE    MELBOURNE  Jan-84            50817             711
# ...         ...          ...     ...              ...             ...
# 25962    SYDNEY  WAGGA WAGGA  Apr-22            11318             326
# 25963    SYDNEY  WAGGA WAGGA  May-22            12278             351
# 25964    SYDNEY  WAGGA WAGGA  Jun-22            12119             338
# 25965    SYDNEY  WAGGA WAGGA  Jul-22            12863             415
# 25966    SYDNEY  WAGGA WAGGA  Aug-22            12971             443
#
#        Route_Distance  Seats  Total_Distance
# 1                1622   4210           51904
# 2                 972   1414           11664
# 3                2619   4566           86427
# 4                1607   1803           25712
# 5                 643  76647          457173
# ...               ...    ...             ...
# 25962             367  17244          119642
# 25963             367  18599          128817
# 25964             367  18116          124046
# 25965             367  20302          152305
# 25966             367  21366          162581
#
# [25966 rows x 8 columns]

# %% [markdown]
# Selecting what columns you want to keep (using loc or iloc) is also viable.
#
# If removal is conditional, then you need to remove with filtering.

# %%
# removing all rows with 0 aircraft trips
flights[flights['Aircraft_Trips'] != 0]
# Out:
#           City1          City2   Month  Passenger_Trips  Aircraft_Trips  \
# 0      ADELAIDE  ALICE SPRINGS  Jan-84            15743             143
# 1      ADELAIDE       BRISBANE  Jan-84             3781              32
# 2      ADELAIDE       CANBERRA  Jan-84             1339              12
# 3      ADELAIDE         DARWIN  Jan-84             3050              33
# 4      ADELAIDE     GOLD COAST  Jan-84             1596              16
# ...         ...            ...     ...              ...             ...
# 25962    SYDNEY    WAGGA WAGGA  Apr-22            11318             326
# 25963    SYDNEY    WAGGA WAGGA  May-22            12278             351
# 25964    SYDNEY    WAGGA WAGGA  Jun-22            12119             338
# 25965    SYDNEY    WAGGA WAGGA  Jul-22            12863             415
# 25966    SYDNEY    WAGGA WAGGA  Aug-22            12971             443
#
#        Route_Distance  Seats  Total_Distance
# 0                1316  19246          188188
# 1                1622   4210           51904
# 2                 972   1414           11664
# 3                2619   4566           86427
# 4                1607   1803           25712
# ...               ...    ...             ...
# 25962             367  17244          119642
# 25963             367  18599          128817
# 25964             367  18116          124046
# 25965             367  20302          152305
# 25966             367  21366          162581
#
# [24000 rows x 8 columns]

# %% [markdown]
# ### Changing the index
#
# You can change the index of a dataframe with the <code>set_index</code> method. Note that this will remove the old index. You can move the old index to a column with assignment.

# %%
# example: setting Month column to be the index
flights.set_index('Month')
# Out:
#            City1          City2  Passenger_Trips  Aircraft_Trips  \
# Month
# Jan-84  ADELAIDE  ALICE SPRINGS            15743             143
# Jan-84  ADELAIDE       BRISBANE             3781              32
# Jan-84  ADELAIDE       CANBERRA             1339              12
# Jan-84  ADELAIDE         DARWIN             3050              33
# Jan-84  ADELAIDE     GOLD COAST             1596              16
# ...          ...            ...              ...             ...
# Apr-22    SYDNEY    WAGGA WAGGA            11318             326
# May-22    SYDNEY    WAGGA WAGGA            12278             351
# Jun-22    SYDNEY    WAGGA WAGGA            12119             338
# Jul-22    SYDNEY    WAGGA WAGGA            12863             415
# Aug-22    SYDNEY    WAGGA WAGGA            12971             443
#
#         Route_Distance  Seats  Total_Distance
# Month
# Jan-84            1316  19246          188188
# Jan-84            1622   4210           51904
# Jan-84             972   1414           11664
# Jan-84            2619   4566           86427
# Jan-84            1607   1803           25712
# ...                ...    ...             ...
# Apr-22             367  17244          119642
# May-22             367  18599          128817
# Jun-22             367  18116          124046
# Jul-22             367  20302          152305
# Aug-22             367  21366          162581
#
# [25967 rows x 7 columns]

# %% [markdown]
# ### Changing column names
#
# Column names can be changed using the <code>rename method</code>. For this, you should supply a <code>columns</code> argument which is a dictionary. The dictionary keys are the old names, and the dictionary values are the new names.

# %%
# changing seats column name
flights.rename(columns = {'Seats': 'Total_Seats'})
# Out:
#           City1          City2   Month  Passenger_Trips  Aircraft_Trips  \
# 0      ADELAIDE  ALICE SPRINGS  Jan-84            15743             143
# 1      ADELAIDE       BRISBANE  Jan-84             3781              32
# 2      ADELAIDE       CANBERRA  Jan-84             1339              12
# 3      ADELAIDE         DARWIN  Jan-84             3050              33
# 4      ADELAIDE     GOLD COAST  Jan-84             1596              16
# ...         ...            ...     ...              ...             ...
# 25962    SYDNEY    WAGGA WAGGA  Apr-22            11318             326
# 25963    SYDNEY    WAGGA WAGGA  May-22            12278             351
# 25964    SYDNEY    WAGGA WAGGA  Jun-22            12119             338
# 25965    SYDNEY    WAGGA WAGGA  Jul-22            12863             415
# 25966    SYDNEY    WAGGA WAGGA  Aug-22            12971             443
#
#        Route_Distance  Total_Seats  Total_Distance
# 0                1316        19246          188188
# 1                1622         4210           51904
# 2                 972         1414           11664
# 3                2619         4566           86427
# 4                1607         1803           25712
# ...               ...          ...             ...
# 25962             367        17244          119642
# 25963             367        18599          128817
# 25964             367        18116          124046
# 25965             367        20302          152305
# 25966             367        21366          162581
#
# [25967 rows x 8 columns]

# %% [markdown]
# ### Changing column order
#
# Column order is easily changed through column selection. Columns will appear in the order they are selected.

# %%
# moving month to the left column
flights.iloc[:, [2, 0, 1, 3, 4, 5, 6, 7]]
# Out:
#         Month     City1          City2  Passenger_Trips  Aircraft_Trips  \
# 0      Jan-84  ADELAIDE  ALICE SPRINGS            15743             143
# 1      Jan-84  ADELAIDE       BRISBANE             3781              32
# 2      Jan-84  ADELAIDE       CANBERRA             1339              12
# 3      Jan-84  ADELAIDE         DARWIN             3050              33
# 4      Jan-84  ADELAIDE     GOLD COAST             1596              16
# ...       ...       ...            ...              ...             ...
# 25962  Apr-22    SYDNEY    WAGGA WAGGA            11318             326
# 25963  May-22    SYDNEY    WAGGA WAGGA            12278             351
# 25964  Jun-22    SYDNEY    WAGGA WAGGA            12119             338
# 25965  Jul-22    SYDNEY    WAGGA WAGGA            12863             415
# 25966  Aug-22    SYDNEY    WAGGA WAGGA            12971             443
#
#        Route_Distance  Seats  Total_Distance
# 0                1316  19246          188188
# 1                1622   4210           51904
# 2                 972   1414           11664
# 3                2619   4566           86427
# 4                1607   1803           25712
# ...               ...    ...             ...
# 25962             367  17244          119642
# 25963             367  18599          128817
# 25964             367  18116          124046
# 25965             367  20302          152305
# 25966             367  21366          162581
#
# [25967 rows x 8 columns]

# %% [markdown]
# ### Data type conversions
#
# Data type conversions can be done with the <code>astype method</code>. For this, you supply a dictionary where the keys are the column names, and the values are the data type to convert to.

# %%
# example: converting seats column to a string
flights = flights.astype({'Seats': str})
flights.dtypes
# Out:
# City1              object
# City2              object
# Month              object
# Passenger_Trips     int64
# Aircraft_Trips      int64
# Route_Distance      int64
# Seats              object
# Total_Distance      int64
# dtype: object
