# %% [markdown]
# ## Elementwise Operations
# Pandas series and dataframes support elementwise operations. An elementwise operation is one that is performed on each element of the series/dataframe. This gives us a convenient way to update columns or to create new columns that are computed from other columns in the dataframe.
#
# Consider the pollution dataset below.

# %%
import pandas as pd
pollution_data = pd.read_csv('LSTM-Multivariate_pollution.csv', index_col = 'date', parse_dates = True)

# %% [markdown]
# Suppose the 'temp' column was currently measured in Celsius and we wanted to convert to Fahrenheit. We could create a new column with the code:

# %%
pollution_data['temp_Fahrenheit'] = pollution_data['temp'] * 9 / 5 + 32
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  -4.0  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  -4.0  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  -5.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  -5.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  -5.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  -2.0  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  -3.0  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  -3.0  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  -4.0  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  -3.0  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit
# date
# 2/01/2010 0:00               24.8
# 2/01/2010 1:00               24.8
# 2/01/2010 2:00               23.0
# 2/01/2010 3:00               23.0
# 2/01/2010 4:00               23.0
# ...                           ...
# 31/12/2014 19:00             28.4
# 31/12/2014 20:00             26.6
# 31/12/2014 21:00             26.6
# 31/12/2014 22:00             24.8
# 31/12/2014 23:00             26.6
#
# [43800 rows x 9 columns]

# %% [markdown]
# Notice that the operations are performed elementwise (to each element of the temp column). You could alternatively replace the 'temp' column if you preferred.

# %%
pollution_data['temp'] = pollution_data['temp'] * 9 / 5 + 32
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  24.8  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  24.8  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  23.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  23.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  23.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  28.4  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  26.6  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  26.6  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  24.8  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  26.6  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit
# date
# 2/01/2010 0:00               24.8
# 2/01/2010 1:00               24.8
# 2/01/2010 2:00               23.0
# 2/01/2010 3:00               23.0
# 2/01/2010 4:00               23.0
# ...                           ...
# 31/12/2014 19:00             28.4
# 31/12/2014 20:00             26.6
# 31/12/2014 21:00             26.6
# 31/12/2014 22:00             24.8
# 31/12/2014 23:00             26.6
#
# [43800 rows x 9 columns]

# %% [markdown]
# Elementwise computations can also involve multiple columns of a dataframe. For example, if we wanted to create a column 'snow and rain' which is an elementwise addition of the 'snow' and the 'rain' columns. We would simply type:

# %%
pollution_data['snow and rain'] = pollution_data['snow'] + pollution_data['rain']
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  24.8  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  24.8  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  23.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  23.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  23.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  28.4  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  26.6  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  26.6  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  24.8  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  26.6  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit  snow and rain
# date
# 2/01/2010 0:00               24.8              0
# 2/01/2010 1:00               24.8              0
# 2/01/2010 2:00               23.0              0
# 2/01/2010 3:00               23.0              1
# 2/01/2010 4:00               23.0              2
# ...                           ...            ...
# 31/12/2014 19:00             28.4              0
# 31/12/2014 20:00             26.6              0
# 31/12/2014 21:00             26.6              0
# 31/12/2014 22:00             24.8              0
# 31/12/2014 23:00             26.6              0
#
# [43800 rows x 10 columns]

# %% [markdown]
# You should recall from the previous page that comparisons are also elementwise. We can use this to compute new columns. For example, if we wanted a column 'is_rain' which is True when there is rain and False when there is no rain. We could type:

# %%
pollution_data['is_rain'] = pollution_data['rain'] > 0
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  24.8  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  24.8  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  23.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  23.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  23.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  28.4  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  26.6  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  26.6  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  24.8  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  26.6  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit  snow and rain  is_rain
# date
# 2/01/2010 0:00               24.8              0    False
# 2/01/2010 1:00               24.8              0    False
# 2/01/2010 2:00               23.0              0    False
# 2/01/2010 3:00               23.0              1    False
# 2/01/2010 4:00               23.0              2    False
# ...                           ...            ...      ...
# 31/12/2014 19:00             28.4              0    False
# 31/12/2014 20:00             26.6              0    False
# 31/12/2014 21:00             26.6              0    False
# 31/12/2014 22:00             24.8              0    False
# 31/12/2014 23:00             26.6              0    False
#
# [43800 rows x 11 columns]

# %% [markdown]
# ***
# ## The apply method
# While elementwise use of simple operators is supported by Pandas, functions generally speaking will not be applied elementwise to series and dataframes. For example, if we wanted our 'is_rain' column to say 'wet' when there is rain and 'dry' when there is no rain, one could propose the function:

# %%
def is_rain(rain):
    if rain > 0:
        return 'wet'
    else:
        return 'dry'

# %% [markdown]
# If we try to call this on the rain column like below we will get an error. This is because the function tries to apply the function to the column holistically rather than for each element of the column.

# %%
pollution_data['is_rain'] = is_rain(pollution_data['rain'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_910/2971333875.py in ?()
# ----> 1 pollution_data['is_rain'] = is_rain(pollution_data['rain'])
#
# /tmp/ipykernel_910/4095067222.py in ?(rain)
#       1 def is_rain(rain):
# ----> 2     if rain > 0:
#       3         return 'wet'
#       4     else:
#       5         return 'dry'
#
# /opt/conda/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# To apply the function for each element, we can use the apply method. In this case, we just supply one argument which is the function we would like to apply elementwise.

# %%
pollution_data['is_rain'] = pollution_data['rain'].apply(is_rain)
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  24.8  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  24.8  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  23.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  23.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  23.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  28.4  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  26.6  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  26.6  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  24.8  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  26.6  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit  snow and rain is_rain
# date
# 2/01/2010 0:00               24.8              0     dry
# 2/01/2010 1:00               24.8              0     dry
# 2/01/2010 2:00               23.0              0     dry
# 2/01/2010 3:00               23.0              1     dry
# 2/01/2010 4:00               23.0              2     dry
# ...                           ...            ...     ...
# 31/12/2014 19:00             28.4              0     dry
# 31/12/2014 20:00             26.6              0     dry
# 31/12/2014 21:00             26.6              0     dry
# 31/12/2014 22:00             24.8              0     dry
# 31/12/2014 23:00             26.6              0     dry
#
# [43800 rows x 11 columns]

# %% [markdown]
# In this example, we called the apply method on a series. We can also call the apply method on a dataframe. For example, if we wanted a new column called weather that is 'wet' when there is rain, 'snow' when there is snow and 'dry' if there is no rain or snow. This involved looking at two columns which would form a dataframe. We could define a function like so:

# %%
def weather(df):
    if df['rain'] > 0:
        return 'rain'
    elif df['snow'] > 0:
        return 'snow'
    else:
        return 'dry'

# %% [markdown]
# To apply it elementwise to each row, we would call the apply method like so:

# %%
pollution_data['weather'] = pollution_data.apply(weather, axis = 1)
pollution_data
# Out:
#                   pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain  \
# date
# 2/01/2010 0:00          129  -16  24.8  1020.0      SE     1.79     0     0
# 2/01/2010 1:00          148  -15  24.8  1020.0      SE     2.68     0     0
# 2/01/2010 2:00          159  -11  23.0  1021.0      SE     3.57     0     0
# 2/01/2010 3:00          181   -7  23.0  1022.0      SE     5.36     1     0
# 2/01/2010 4:00          138   -7  23.0  1022.0      SE     6.25     2     0
# ...                     ...  ...   ...     ...     ...      ...   ...   ...
# 31/12/2014 19:00          8  -23  28.4  1034.0      NW   231.97     0     0
# 31/12/2014 20:00         10  -22  26.6  1034.0      NW   237.78     0     0
# 31/12/2014 21:00         10  -22  26.6  1034.0      NW   242.70     0     0
# 31/12/2014 22:00          8  -22  24.8  1034.0      NW   246.72     0     0
# 31/12/2014 23:00         12  -21  26.6  1034.0      NW   249.85     0     0
#
#                   temp_Fahrenheit  snow and rain is_rain weather
# date
# 2/01/2010 0:00               24.8              0     dry     dry
# 2/01/2010 1:00               24.8              0     dry     dry
# 2/01/2010 2:00               23.0              0     dry     dry
# 2/01/2010 3:00               23.0              1     dry    snow
# 2/01/2010 4:00               23.0              2     dry    snow
# ...                           ...            ...     ...     ...
# 31/12/2014 19:00             28.4              0     dry     dry
# 31/12/2014 20:00             26.6              0     dry     dry
# 31/12/2014 21:00             26.6              0     dry     dry
# 31/12/2014 22:00             24.8              0     dry     dry
# 31/12/2014 23:00             26.6              0     dry     dry
#
# [43800 rows x 12 columns]

# %% [markdown]
# Notice that in this case we need to provide a second argument. By default, the apply method will perform element-wise application of the function for each column. To specify that the function needs to be applied for each row, you need the axis = 1 argument.
